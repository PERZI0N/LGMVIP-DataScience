# %% [markdown]
# # Task1: Iris Flowers Classification ML Project
#
# Author: Jahnavi Gundakaram

# %% [markdown]
# # Import modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Loading dataset

# %%
iris_flowers = pd.read_csv('iris.data')

# %%
iris_flowers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_flowers['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# #  Data Analysis

# %%
iris_flowers['SepalLengthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
iris_flowers['SepalWidthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
iris_flowers['PetalLengthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
iris_flowers['PetalWidthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
colors = ['red','green','blue']
Species = ['Iris-versicolor','Iris-virginica','Iris-setosa']

# %%
for i in range(3):
    x = iris_flowers[iris_flowers['Species']==Species[i]]
    plt.scatter(x['SepalLengthCm'],x['SepalWidthCm'], c=colors[i], label=Species[i])
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.legend()

# %%
for i in range(3):
    x = iris_flowers[iris_flowers['Species']==Species[i]]
    plt.scatter(x['PetalLengthCm'],x['PetalWidthCm'], c=colors[i], label=Species[i])
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.legend()

# %%
# from the above plot it can be observed that 'Iris-setosa' can be easily classified from others.

# %%
for i in range(3):
    x = iris_flowers[iris_flowers['Species']==Species[i]]
    plt.scatter(x['SepalLengthCm'],x['PetalLengthCm'], c=colors[i], label=Species[i])
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.legend()

# %%
for i in range(3):
    x = iris_flowers[iris_flowers['Species']==Species[i]]
    plt.scatter(x['SepalWidthCm'],x['PetalWidthCm'], c=colors[i], label=Species[i])
plt.xlabel("Sepal Width")
plt.ylabel("Petal Width")
plt.legend()

# %%
sns.violinplot(y='Species', x='SepalLengthCm', data = iris_flowers, inner='quartile',hue = 'SepalLengthCm')
plt.show()

# %%
sns.violinplot(y='Species', x='SepalWidthCm', data = iris_flowers, inner='quartile',hue = 'SepalWidthCm')
plt.show()

# %%
sns.violinplot(y='Species', x='PetalLengthCm', data = iris_flowers, inner='quartile',hue='PetalLengthCm')
plt.show()

# %%
sns.violinplot(y='Species', x= 'PetalWidthCm', data = iris_flowers, inner='quartile', hue='PetalWidthCm')
plt.show()

# %% [markdown]
# # Correlation Matrix

# %%
iris_flowers.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
corr = iris_flowers.corr()
fig, ax = plt.subplots(figsize=(5,4))
sns.heatmap(corr, annot=True, ax = ax, cmap = 'YlGnBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
iris_flowers['Species']=le.fit_transform(iris_flowers['Species'])

# %%
iris_flowers.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import train_test_split
X=iris_flowers.drop(columns=['Species'])
Y=iris_flowers['Species']
x_train, x_test, y_train, y_test=train_test_split(X,Y,test_size=0.30)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
print("Accuracy:",model.score(x_test,y_test)*100)
# Out:
# Accuracy: 97.77777777777777

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
print("Accuracy:",model.score(x_test,y_test)*100)
# Out:
# Accuracy: 97.77777777777777

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy:",model.score(x_test,y_test)*100)
# Out:
# Accuracy: 97.77777777777777
